# %% [markdown]
# Name : Espinas, Charles Vence R.
#
# Course Code and Title : CPE031 | Visualization and Data Analysis
#
# Date Submitted : 10/16/2025
#
# Instructor : Mrs. Maria Rizette Sayo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Exploring Data Visually**
#
#
#
#
#
# ---

# %% [markdown]
# **Discussions:**
#
# Exploratory Data Analysis (EDA) is the process of analyzing datasets to summarize their main characteristics and gain insights before formal modeling. Visual exploration helps identify trends, relationships, and data quality issues.
#
# Key Components:
#
# Univariate Analysis:
# Analyzing one variable at a time (e.g., histograms, bar charts).
#
# Bivariate Analysis:
# Exploring relationships between two variables (e.g., scatterplots, crosstabs).
#
# Missing Data Analysis:
# Identifying and handling missing or null values.
#
# Time-Series Visualization:
# Displaying data across time to reveal trends or seasonality.
#
# Geospatial Visualization:
# Mapping data to geographical regions to identify spatial patterns.
#
# EDA is both an art and science combining statistical summaries with visual intuition.

# %% [markdown]
# **Procedures:**

# %% [markdown]
# **Color and Perception**

# %% [markdown]
# Section 1: Organizing and Exploring Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Sample dataset
data = {
    "Product": ["Juice", "Smoothie", "Juice", "Smoothie", "Juice", "Smoothie"],
    "Region": ["North", "South", "East", "West", "North", "East"],
    "Sales": [120, 150, 90, 110, 130, 170],
    "Profit": [30, 45, 20, 25, 35, 50]
}
df = pd.DataFrame(data)

# Display the dataset
df
# Out:
#     Product Region  Sales  Profit
# 0     Juice  North    120      30
# 1  Smoothie  South    150      45
# 2     Juice   East     90      20
# 3  Smoothie   West    110      25
# 4     Juice  North    130      35
# 5  Smoothie   East    170      50

# %% [markdown]
# Task 1: Analyzing Variables One at a Time

# %%
#Categorical Variable
# Countplot for categorical variable
sns.countplot(x="Region", data=df, palette="Set2")
plt.title("Frequency of Sales by Region")
plt.show()
# Out:
# /tmp/ipython-input-2975764973.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Region", data=df, palette="Set2")

# %%
#Quantitative Variable
# Histogram for quantitative variable
plt.hist(df["Sales"], bins=5, color="skyblue", edgecolor="black")
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Task: <br>
# Create one countplot for Product and one histogram for Profit. <br>
# Compare their patterns and interpret what they mean.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Countplot for Product
sns.countplot(x="Product", data=df, palette="viridis")
plt.title("Frequency of Sales by Product Type")
plt.show()

# Histogram for Profit
plt.hist(df["Profit"], bins=5, color="salmon", edgecolor="black")
plt.title("Distribution of Profit")
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.show()
# Out:
# /tmp/ipython-input-4164374807.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Product", data=df, palette="viridis")

# %% [markdown]
# **Based on my analysis about the scatterplot and the crosstabulation that I make, I observe in the scatterplot of Sales vs Profit that Sales and Profit has a positive relationwhip which indicates that as Sales increases, the Profit also tends to increase.  The points are colored by Region which allows us to see how each regionn's sales and profit relate. I observe by looking at the Region and Product of the crosstabulation, it shows there the average sales. Which shows that the East region appears to perform  best with the highet average sales for Smoothies and a good average for Juice in this sample data. This shows that the East Region is a strong performer in terms of sales volume.**

# %%
# Scatterplot: Sales vs Profit
sns.scatterplot(x="Sales", y="Profit", hue="Region", data=df, palette="coolwarm", s=100)
plt.title("Relationship between Sales and Profit")
plt.show()

# %%
# Crosstabulation example
pd.crosstab(df["Region"], df["Product"], values=df["Sales"], aggfunc="mean").fillna(0)
# Out:
# Product  Juice  Smoothie
# Region
# East      90.0     170.0
# North    125.0       0.0
# South      0.0     150.0
# West       0.0     110.0

# %% [markdown]
# Task: <br>
# Interpret whether higher sales also mean higher profit. <br>
# Which region seems to perform best?

# %% [markdown]
# **Based on my analysis of the scatterplot  and crosstabulation, the Higher the sales is,the higher the profit. Which we can see in the positive trend in the scatter plot.The region that performs the bestis the East reigon and the reason why is because the East region has  the highest average sales figures.**

# %% [markdown]
# Section 3: Analysis of Missing Data

# %%
# Introduce missing data
df_missing = df.copy()
df_missing.loc[2, "Profit"] = np.nan
df_missing.loc[5, "Sales"] = np.nan

# Visualize missing data
sns.heatmap(df_missing.isnull(), cbar=False, cmap="Reds")
plt.title("Missing Data Visualization")
plt.show()

# Display missing summary
df_missing.isnull().sum()
# Out:
# Product    0
# Region     0
# Sales      1
# Profit     1
# dtype: int64

# %% [markdown]
# Task: <br>
# Describe what you observe in the missing data visualization. <br>
# Which variables need attention before analysis?

# %% [markdown]
# **Based on the given heat map graph  which labeled as Missing Data Visualiation, the heatmap shows missing values in the Sales and Profit columns. I observe that these  red areas inthe graph indicates where the missing values are located. Therefore, the variables that needed attention before analysis is the Sales and Profit variables because they  are the ones that has a missing data.**

# %% [markdown]
# Section 4: Visualizing Time-Series Data

# %%
# Generate time-series example
dates = pd.date_range(start="2024-01-01", periods=10)
sales = np.random.randint(80, 200, 10)
ts_df = pd.DataFrame({"Date": dates, "Sales": sales})

# Line chart for time-series
plt.plot(ts_df["Date"], ts_df["Sales"], marker="o", color="teal")
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %% [markdown]
# Task: <br>
# Add a moving average line (rolling mean) to smooth fluctuations. <br>
# Hint: Use ts_df["Sales"].rolling(window=3).mean().

# %%
# Generate time-series example
dates = pd.date_range(start="2024-01-01", periods=10)
sales = np.random.randint(80, 200, 10)
ts_df = pd.DataFrame({"Date": dates, "Sales": sales})

# Add a moving average line (rolling mean)
ts_df["Sales_Rolling_Mean"] = ts_df["Sales"].rolling(window=3).mean()

# Line chart for time-series with rolling mean
plt.plot(ts_df["Date"], ts_df["Sales"], marker="o", color="teal", label="Sales")
plt.plot(ts_df["Date"], ts_df["Sales_Rolling_Mean"], color="red", linestyle="--", label="3-Period Rolling Mean")
plt.title("Sales Over Time with Rolling Mean")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.legend()
plt.xticks(rotation=45) # Rotate x-axis labels
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# Section 5: Visualizing Geospatial Data

# %%
import geopandas as gpd
from shapely.geometry import Point

# Sample coordinates (latitude, longitude)
coords = {
    "Branch": ["North", "South", "East", "West"],
    "Latitude": [15.5, 8.5, 13.0, 10.5],
    "Longitude": [120.9, 123.0, 125.0, 122.0],
    "Sales": [120, 150, 90, 110]
}

geo_df = pd.DataFrame(coords)
geo_df["geometry"] = [Point(xy) for xy in zip(geo_df.Longitude, geo_df.Latitude)]
gdf = gpd.GeoDataFrame(geo_df, geometry="geometry")

# Plot simple map (Philippines outline optional if available)
gdf.plot(column="Sales", cmap="Blues", legend=True, markersize=geo_df["Sales"])
plt.title("Geospatial Visualization of Sales by Branch")
plt.show()

# %% [markdown]
# Task: <br>
# Interpret which branch has the highest sales geographically. <br>
# How can such visualization help in business decision-making?

# %% [markdown]
# **Based on the geospatial visualization that has been provided in this activity, the South branch appears to have the highest sales geographically which is evident from the largest market size on the map. This type of visualization is important and helpful for business decision making because it allows for the quick  identificationof the best performing locations which enables better allocationof resources like marketing and inventory. It also highlights areas forpotential expnsion or improvement based on the sales  performace  and reveals spatial sales patterns that could be influenced by variou geographical fctors**

# %% [markdown]
# **CONCLUSION**
#
# **In this hands on activity, we explored sales and profit data for different product and regions. We used a countplots and histograms to understand the frequencyof products and the distributionof the profit. I oserve that the scatterplot revealed a positive relationship between the sales and the profit withthe crosstabulation highlighting the East region's strong performnce inaverage sales. By analyzing the missing data, we can know that both Sales and Profit variable had mising values which requires an attentionbefore anlyizing them. Lastly, atime series plot with a rolling mean helped me visualize the sales trends overtime and a geospatialplot wwhich I identify that the South branch is the highest geographicalsales.**
